# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/FTDS-learning-materials/phase-0/main/src/teams.csv")
df.tail(10)
# Out:
#                       division conference               school_name  \
# 242  FCS (Division I-AA Teams)       SWAC               Alabama A&M
# 243  FCS (Division I-AA Teams)       SWAC             Alabama State
# 244  FCS (Division I-AA Teams)       SWAC              Alcorn State
# 245  FCS (Division I-AA Teams)       SWAC       Arkansas-Pine Bluff
# 246  FCS (Division I-AA Teams)       SWAC           Grambling State
# 247  FCS (Division I-AA Teams)       SWAC             Jackson State
# 248  FCS (Division I-AA Teams)       SWAC  Mississippi Valley State
# 249  FCS (Division I-AA Teams)       SWAC          Prairie View A&M
# 250  FCS (Division I-AA Teams)       SWAC       Southern University
# 251  FCS (Division I-AA Teams)       SWAC            Texas Southern
#
#                                           roster_url   id
# 242  http://espn.go.com/ncf/teams/roster?teamId=2010  243
# 243  http://espn.go.com/ncf/teams/roster?teamId=2011  244
# ...

# %%
df.shape
# Out:
# (252, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   division     252 non-null    object
#  1   conference   252 non-null    object
#  2   school_name  252 non-null    object
#  3   roster_url   252 non-null    object
#  4   id           252 non-null    int64
# dtypes: int64(1), object(4)
# memory usage: 10.0+ KB

# %%
df.describe()
df.index
df.dtypes
df.isnull()
df.nunique()
df.value_counts()
# Out:
# division                   conference        school_name        roster_url                                       id
# FBS (Division I-A Teams)   ACC               Boston College     http://espn.go.com/ncf/teams/roster?teamId=103   11     1
# FCS (Division I-AA Teams)  MEAC              Howard             http://espn.go.com/ncf/teams/roster?teamId=47    174    1
#                            FCS Independents  Monmouth           http://espn.go.com/ncf/teams/roster?teamId=2405  161    1
#                            Ivy               Brown              http://espn.go.com/ncf/teams/roster?teamId=225   162    1
#                                              Columbia           http://espn.go.com/ncf/teams/roster?teamId=171   163    1
#                                                                                                                        ..
# FBS (Division I-A Teams)   Mountain West     San Jose State     http://espn.go.com/ncf/teams/roster?teamId=23    89     1
# ...

# %%
df["division"].value_counts()
df["conference"].value_counts()
# Out:
# conference
# Conference USA       14
# SEC                  14
# ACC                  14
# Mid-American         13
# Big Sky              13
# Pioneer              12
# Big Ten              12
# Mountain West        12
# Pac-12               12
# CAA                  11
# MEAC                 11
# American Athletic    10
# Missouri Valley      10
# SWAC                 10
# Big 12               10
# Ohio Valley           9
# Southern              9
# Ivy                   8
# Sun Belt              8
# Southland             8
# FBS Independents      7
# Northeast             7
# Patriot League        7
# Big South             6
# FCS Independents      5
# Name: count, dtype: int64

# %%
df.sort_values(by="school_name", inplace=True)
df
# Out:
#                       division        conference        school_name  \
# 156  FCS (Division I-AA Teams)  FCS Independents  Abilene Christian
# 80    FBS (Division I-A Teams)     Mountain West          Air Force
# 67    FBS (Division I-A Teams)      Mid-American              Akron
# 104   FBS (Division I-A Teams)               SEC            Alabama
# 242  FCS (Division I-AA Teams)              SWAC        Alabama A&M
# ..                         ...               ...                ...
# 45    FBS (Division I-A Teams)           Big Ten          Wisconsin
# 233  FCS (Division I-AA Teams)          Southern            Wofford
# 91    FBS (Division I-A Teams)     Mountain West            Wyoming
# 168  FCS (Division I-AA Teams)               Ivy               Yale
# 189  FCS (Division I-AA Teams)   Missouri Valley   Youngstown State
#
#                                           roster_url   id
# 156  http://espn.go.com/ncf/teams/roster?teamId=2000  157
# ...

# %%
df["school_name"]
df[["school_name", "id"]]

df.iloc[0]

tsv_df = pd.read_csv('https://raw.githubusercontent.com/FTDS-learning-materials/phase-0/main/src/cities_world.tsv', delimiter='\t')
tsv_df.set_index("City", inplace=True)
tsv_df.loc[tsv_df["Density"] > 9000]
# Out:
#                    Latitude   Longitude      Country  Population  Land_area  \
# City
# Seoul/Incheon     37.566500  126.978000  South Korea    17500000       1049
# Manila            14.599500  120.984200  Philippines    14750000       1399
# Mumbai            19.076000   72.877700        India    14350000        484
# Delhi             28.704100   77.102500        India    14300000       1295
# Jakarta           -6.174500  106.822700    Indonesia    14250000       1360
# Lagos              6.524400    3.379200      Nigeria    13400000        738
# Kolkata           22.572600   88.363900        India    12700000        531
# Cairo             30.044400   31.235700        Egypt    12200000       1295
# Shanghai          31.230400  121.473700        China    10000000        746
# Karachi           24.861500   67.009900     Pakistan     9800000        518
# Beijing           39.904200  116.407400        China     8614000        748
# ...

# %%
df[(df["conference"] == "American Athletic") & (df["school_name"] == "Connecticut")]
df[~(df["conference"] == "American Athletic")]
df.query("conference == 'American Athletic'")
df.query("conference == 'American Athletic' and school_name == 'Connecticut'")
df[df["id"].isin([11, 12, 13])]
df[df["school_name"].str.contains("Arkansas")]
# Out:
#                       division conference          school_name  \
# 105   FBS (Division I-A Teams)        SEC             Arkansas
# 118   FBS (Division I-A Teams)   Sun Belt       Arkansas State
# 245  FCS (Division I-AA Teams)       SWAC  Arkansas-Pine Bluff
# 234  FCS (Division I-AA Teams)  Southland     Central Arkansas
#
#                                           roster_url   id
# 105     http://espn.go.com/ncf/teams/roster?teamId=8  106
# 118  http://espn.go.com/ncf/teams/roster?teamId=2032  119
# 245  http://espn.go.com/ncf/teams/roster?teamId=2029  246
# 234  http://espn.go.com/ncf/teams/roster?teamId=2110  235

# %%
df2 = df.set_index("school_name")
df2.loc["Houston"]
df2.loc[(df2["id"] < 5) | (df2["conference"] == "American Athletic")]

df["new_col"] = 1
df["new2"] = df["id"] * 5
df2._append({'division': 'One', 'conference': 'Walao', 'school_name': 'Connecticut'}, ignore_index=True)
df2
df.drop("new_col", axis=1)
df[~(df["division"] == "FBS (Division I-A Teams)")]
df
df.drop(156)
df.sum()
df["id"].mean()
df["id"].median()
df[['id', 'new2']].agg({'id': 'sum', 'new2': 'mean'})
df.groupby("conference")["id"].count()
df.groupby("conference")["id"].agg(['mean', 'sum', 'count'])
# Out:
#                     mean   sum  count
# conference
# ACC                 17.5   245     14
# American Athletic    5.5    55     10
# Big 12              29.5   295     10
# Big Sky            133.0  1729     13
# Big South          142.5   855      6
# Big Ten             40.5   486     12
# CAA                151.0  1661     11
# Conference USA      53.5   749     14
# FBS Independents    64.0   448      7
# FCS Independents   159.0   795      5
# Ivy                165.5  1324      8
# MEAC               175.0  1925     11
# Mid-American        74.0   962     13
# Missouri Valley    185.5  1855     10
# Mountain West       86.5  1038     12
# Northeast          194.0  1358      7
# Ohio Valley        202.0  1818      9
# Pac-12              98.5  1182     12
# Patriot League     210.0  1470      7
# Pioneer            219.5  2634     12
# SEC                111.5  1561     14
# SWAC               247.5  2475     10
# Southern           230.0  2070      9
# ...

# %%
asd = pd.read_csv("https://raw.githubusercontent.com/FTDS-learning-materials/phase-0/main/src/teams.csv")
asd._append({'division': 'One', 'conference': 'Walao', 'school_name': 'Connecticut'}, ignore_index=True)
asd
# Out:
#                       division         conference               school_name  \
# 0     FBS (Division I-A Teams)  American Athletic                Cincinnati
# 1     FBS (Division I-A Teams)  American Athletic               Connecticut
# 2     FBS (Division I-A Teams)  American Athletic                   Houston
# 3     FBS (Division I-A Teams)  American Athletic                Louisville
# 4     FBS (Division I-A Teams)  American Athletic                   Memphis
# ..                         ...                ...                       ...
# 247  FCS (Division I-AA Teams)               SWAC             Jackson State
# 248  FCS (Division I-AA Teams)               SWAC  Mississippi Valley State
# 249  FCS (Division I-AA Teams)               SWAC          Prairie View A&M
# 250  FCS (Division I-AA Teams)               SWAC       Southern University
# 251  FCS (Division I-AA Teams)               SWAC            Texas Southern
#
# ...
