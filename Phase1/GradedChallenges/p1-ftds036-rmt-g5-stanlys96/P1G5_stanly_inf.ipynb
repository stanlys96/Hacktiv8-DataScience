# %% [markdown]
# # x. Model Inference

# %%
import pandas as pd
import numpy as np
import pickle

# %%
with open('model.pkl', 'rb') as file_1:
  model = pickle.load(file_1)

# %%
model
# Out:
# Pipeline(steps=[('feature_engineering',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   Pipeline(steps=[('imputation',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaling',
#                                                                    MinMaxScaler())]),
#                                                   ['time_on_site',
#                                                    'pageviews']),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('encoding',
#                                                                    OneHotEncoder())]),
#                                                   ['latest_ecommerce_progress',
#                                                    'bounces', 'medium',
# ...

# %% [markdown]
# ### 9. Buatlah Model Inference dari model yang terbaik dan dengan data berikut:

# %%
data = { 
       'latest_ecommerce_progress': [5,4], 
       'bounces': [0,0], 
       'time_on_site': [2489, 436], 
       'pageviews': [30, 50], 
       'source': ['google','google'],
       'medium': ['organic', 'referral'],
       'channelGrouping': ['Organic Search','Organic Search'],
       'deviceCategory': ['desktop', 'desktop'],
       'country': ['Canada',np.nan]
       }

df = pd.DataFrame(data)

# %%
df
# Out:
#    latest_ecommerce_progress  bounces  time_on_site  pageviews  source  \
# 0                          5        0          2489         30  google
# 1                          4        0           436         50  google
#
#      medium channelGrouping deviceCategory country
# 0   organic  Organic Search        desktop  Canada
# 1  referral  Organic Search        desktop     NaN

# %%
# menyimpan hasil prediksi
prediction = model.predict(df)

# %%
for index, data in enumerate(prediction):
  print(f'Pengunjung {index + 1} diprediksi {int(data)}, yang berarti: pengunjung{" tidak" if int(data) == 0 else ""} akan melakukan pembelian saat mengunjungi kembali situs web')
# Out:
# Pengunjung 1 diprediksi 0, yang berarti: pengunjung tidak akan melakukan pembelian saat mengunjungi kembali situs web
# Pengunjung 2 diprediksi 0, yang berarti: pengunjung tidak akan melakukan pembelian saat mengunjungi kembali situs web

# %% [markdown]
# # xi. Pengambilan Kesimpulan

# %% [markdown]
# Kesimpulan yang bisa diambil dari proses ini adalah, dataset_1 tidak bisa diandalkan untuk memprediksi potensi pembelian user ketika user mengunjungi kembali website tersebut, maka dataset_2 lah yang digunakan. Pada akhirnya, ada beberapa kolom yang harus di drop, karena kardinalitas yang tinggi. Dari data-data penunjang yang ada, bisa dibilang bahwa data-data tersebut cukup bisa diandalkan untuk memberikan prediksi, karena hasil AUC Score akhir pada X_test dan y_test adalah 0.91, yang berarti good-fit. Bisa disimpulkan bahwa, dengan menggunakan machine learning model Logistic Regression, dapat memprediksi potensi pembelian user, dengan akurasi yang cukup tinggi.
